# %% [markdown]
# <a href="https://colab.research.google.com/github/Ian386/DataScienceProjects/blob/main/LuX_CAPSTONE_MOVIE_DATASET_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DATA SCIENCE MOVIE DATASET PROJECT**
#
# ---

# %% [markdown]
# ## **Introduction**
#
#
# In this project, we will be exploring a comprehensive movie dataset sourced from Kaggle to analyze and visualize various trends within the film industry. Movies have long been a significant part of global culture, and understanding the trends and patterns within this industry can provide valuable insights into audience preferences, the popularity of genres, the success of directors, and how these elements have evolved over time.
#
# ## **Objectives**
#
# The primary objectives of this project are:
#
# * **Data Exploration**: Analyze the dataset to explore key aspects such as movie genres, ratings, director popularity, and trends related to the release year.
# * **Data Visualization**: Create interactive dashboards that present these insights in a visually engaging manner, making it easier to identify patterns and trends.
#
# **Content**
#
# The dataset from TMDB contains the follwing columns:
#
#
# budget,
# genres,
# homepage,
# id,
# keywords,
# original_language,
# original_title,
# overview,
# popularity,
# production_companies,
# production_countries,
# release_date,
# revenue,
# runtime,
# spoken_languages,
# status,
# tagline,
# title,
# vote_average, and fiinally
# vote_count
#
# By the end of this project, we aim to gain a deeper understanding of the dynamics of the movie industry and provide a tool that can offer personalized movie recommendations. Let's dive into the data to uncover the stories it holds.

# %% [markdown]
# ## **Data Collection and Cleaning**
#
# Before we dive into story telling, lets first upload our dataset into our notebook and take sneak pick into what we are working with

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('/content/tmdb_5000_movies.csv')
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df.shape
# Out:
# (4803, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %% [markdown]
# We also have a dataset a dataset on movie credits which will prove to be useful in the future to get the Director(s) for each movie.

# %%
df_credits = pd.read_csv('/content/tmdb_5000_credits.csv')
df_credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
df_credits.shape
# Out:
# (4803, 4)

# %% [markdown]
# Its imperative that we merge both dataframe on a common column which proves to the title column

# %%
# Merge the movies and credits dataframes on the 'title' column
df = df.merge(df_credits,on='title')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
# ...

# %% [markdown]
# The dataset looks great, with very informative columns but some need to be removed because they are not important for our current obejectives. Such include:
# * Id, movie_Id
# * Homepage
# * Keywords
# * Production_countries and companies
# * Overview
# * Status
# * Tagline
# * Spoken_languages
# * original_title - duplicated title
# * cast
#
#
# budget, genres, homepage, id, keywords, original_language, original_title, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, vote_average, fiinally vote_count, movie_Id, cast, and finally crew

# %%
# Removing unnecessary columns from the dataset
rem_columns = ['id', 'keywords', 'homepage', 'original_title', 'production_countries', 'status', 'tagline', 'overview', 'spoken_languages', 'movie_id', 'cast', 'production_companies']
df.drop(columns=rem_columns, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             4809 non-null   int64
#  1   genres             4809 non-null   object
#  2   original_language  4809 non-null   object
#  3   popularity         4809 non-null   float64
#  4   release_date       4808 non-null   object
#  5   revenue            4809 non-null   int64
#  6   runtime            4807 non-null   float64
#  7   title              4809 non-null   object
#  8   vote_average       4809 non-null   float64
#  9   vote_count         4809 non-null   int64
#  10  crew               4809 non-null   object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 413.4+ KB

# %% [markdown]
# Now that we have removed the unnecessary cloumns the dataset looks less flooded.
#
# Next we look at whether there are any duplicated rows and missing values on the dataset.

# %%
#search for any duplicated rows in the dataset
df.duplicated().sum()
# Out:
# 0

# %%
#search for any missing values in the data set
df.isnull().sum()
# Out:
# budget               0
# genres               0
# original_language    0
# popularity           0
# release_date         1
# revenue              0
# runtime              2
# title                0
# vote_average         0
# vote_count           0
# crew                 0
# dtype: int64

# %%
#display rows with missing runtime values
df[df['runtime'].isnull()]
# Out:
#         budget                               genres original_language  \
# 2662  15000000        [{"id": 18, "name": "Drama"}]                it
# 4147         2  [{"id": 99, "name": "Documentary"}]                en
#
#       popularity release_date  revenue  runtime  \
# 2662    0.738646   2015-12-03        0      NaN
# 4147    0.050625   2015-12-12        0      NaN
#
#                                            title  vote_average  vote_count  \
# 2662  Chiamatemi Francesco - Il Papa della gente           7.3          12
# 4147                 To Be Frank, Sinatra at 100           0.0           0
#
#                                                    crew
# 2662  [{"credit_id": "5660019ac3a36875f100252b", "de...
# 4147  [{"credit_id": "592b25e4c3a368783e065a2f", "de...

# %%
# release_date and runtime have null value
# fill null values of release_date and fill null runtime with median values
df['release_date'].fillna('', inplace=True)
df['runtime'].fillna(df['runtime'].median(), inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# The dataset is clean. Lets take a step further and correct the datatypes of the values in some of the values to ensure no errors occur in the future

# %%
#Ensure release_data is a datetime object and no null errors occur
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# %%
df.isna().sum()
# Out:
# budget               0
# genres               0
# original_language    0
# popularity           0
# release_date         1
# revenue              0
# runtime              0
# title                0
# vote_average         0
# vote_count           0
# crew                 0
# dtype: int64

# %% [markdown]
# From the dataset we have we want to optimize the columns to display their apprpriate values.
#
#
# For starters, we begin with the crew column where we are only interested with the Director. Lets write some code to filter out the Director from the crew and generate their own column.

# %%
# begin by writing a function to extract the director's name from the crew
import ast
def extract_dir(text):
    Literal = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
          Literal.append(i['name'])
    return Literal


# Apply the function to the crew column
df['crew'] = df['crew'].apply(extract_dir)
# Change the column name to Director
df.rename(columns={'crew': 'director'}, inplace=True)
df['director'].sample(5)
# Out:
# 908         [J.J. Abrams]
# 1679     [Laurent Tirard]
# 1242        [Peter Hyams]
# 872     [Steven Zaillian]
# 2760         [Mark Brown]
# Name: director, dtype: object

# %% [markdown]
# Some of the other  columns have values in a json format including other unnecesary information. We have to create a function that converts the JSON string dictionary and then append the name value into an empty list.
#
# ast.literal_eval() is used to convert string to list

# %%
def convert(obj):
    Literal = []  # empty list
    for i in ast.literal_eval(obj): # convert string to list
        i['name']   # i is a dictionary
        Literal.append(i['name']) # append the name of the genre
    return Literal

df['genres']=df['genres'].apply(convert)
df.head(5)
# Out:
#       budget                                         genres original_language  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]                en
# 1  300000000                   [Adventure, Fantasy, Action]                en
# 2  245000000                     [Action, Adventure, Crime]                en
# 3  250000000               [Action, Crime, Drama, Thriller]                en
# 4  260000000           [Action, Adventure, Science Fiction]                en
#
#    popularity release_date     revenue  runtime  \
# 0  150.437577   2009-12-10  2787965087    162.0
# 1  139.082615   2007-05-19   961000000    169.0
# 2  107.376788   2015-10-26   880674609    148.0
# 3  112.312950   2012-07-16  1084939099    165.0
# 4   43.926995   2012-03-07   284139100    132.0
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# ...

# %% [markdown]
# Doing a quick statistic of the numerical columns in our dataset.

# %%
df.describe()
# Out:
#              budget   popularity                   release_date       revenue  \
# count  4.809000e+03  4809.000000                           4808  4.809000e+03
# mean   2.902780e+07    21.491664  2002-12-23 19:30:44.925124864  8.227511e+07
# min    0.000000e+00     0.000000            1916-09-04 00:00:00  0.000000e+00
# 25%    7.800000e+05     4.667230            1999-07-07 06:00:00  0.000000e+00
# 50%    1.500000e+07    12.921594            2005-10-03 00:00:00  1.917000e+07
# 75%    4.000000e+07    28.350529            2011-02-16 00:00:00  9.291317e+07
# max    3.800000e+08   875.581305            2017-02-03 00:00:00  2.787965e+09
# std    4.070473e+07    31.803366                            NaN  1.628379e+08
#
#            runtime  vote_average    vote_count
# count  4809.000000   4809.000000   4809.000000
# mean    106.880640      6.092514    690.331670
# min       0.000000      0.000000      0.000000
# 25%      94.000000      5.600000     54.000000
# ...

# %% [markdown]
# Now that our dataset is all clean, we can save it for visualizations and get right into exploring it.

# %%
#saving the cleaned dataset
df.to_csv('tmdb_movies_cleaned.csv', index=False)

# %% [markdown]
# ## **2. Data Exploration**

# %% [markdown]
# In this is section, we aim to get a better visual understanding of some of the data columns  and identify insights in our movie dataset which will be helpful to us later on when we are using Tableau to further our visual dashboards.
#
# Some of the fields of interest include: movie genres, ratings distribution, the popularity of directors, and release year patterns.

# %% [markdown]
# ***Budget and revenue***
#
# We can start by looking at how the movies faired financially. To make the visualization easier on the eye, we can focus on the top 10 movies that had the highest revenue and budget in their portfolio.

# %% [markdown]
# But first we will have to convert the Budget and Revenue columns to read in Millions

# %%
df['budget'] = df['budget'] / 1000000
df['budget'] = df['budget'].astype(int)

df['revenue'] = df['revenue'] / 1000000
df['revenue'] = df['revenue'].astype(int)

# %%
# Top 10 movies with the highest budget and revenue
# We are to plot within the same figure, each with its own subplot

plt.figure(figsize=(24,12))
#First subplot
plt.subplot(1,2,1)
plt.title('TOP 10 MOVIES WITH HIGHEST BUDGET')
sns.barplot(y='title', x='budget', data=df[['title', 'budget']].sort_values('budget', ascending=False).head(10), color='purple')
plt.xlabel('Budget in Millions')

# Second subplot
plt.subplot(1,2,2)
plt.title('TOP 10 MOVIES WITH HIGHEST REVENUE')
sns.barplot(y='title', x='revenue', data=df[['title', 'revenue']].sort_values('revenue', ascending=False).head(10), color='yellow')
plt.xlabel('Revenue in Millions')
plt.show()

# %% [markdown]
# The visualization provides a good summary of how the top movies in each category faired.

# %% [markdown]
# ***Original language***
#
# We can also visualize how the 10 top ten spoken languages in the movies
# which were realeased between 1966 and 2017 dominated the dataset

# %%
df['original_language'].value_counts().head(10)
# Out:
# original_language
# en    4510
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# ko      12
# cn      12
# Name: count, dtype: int64

# %% [markdown]
# Its clearly apparent that english was the most dominant original language in the movies that were realesed.

# %% [markdown]
# ***Release dates***
#
# We would also like to see the distribution of production of movies over the years to see which year most movies were released.

# %% [markdown]
# But first we need to get the year_released column and then proceed to plot the bar graph

# %%
df['release_year'] =df['release_date'].dt.year
#bar graph showing movie production over the years
plt.figure(figsize=(24,12))
df['release_year'].value_counts().sort_index().plot(kind='bar', color='orange', width=0.8)
plt.title('Movie Production Over The Years')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.show()

# %% [markdown]
# The bar graph clearly outlines the movie distribution over the years with 2009 topping the charts as the year with the most movie releases.

# %% [markdown]
# ***Genres***
#
# Now for the most fun part, Genres. Tney entail the categories the movies fall into making our main objective, to visualize the most popular genres over the years and their distributions.
#
#
# Since they are in a list format for each record, we will have to create a separate dataset for all the genres categories with the respective year releases of the movies they are related to.
#
# * First we will create an empty dictionary with the year as the key and the genres as values
# * Loop through each year placing each occurrence of a movie category whether they appear in that year or not
# * Count the movie oocurrences with respect to each year and change it to a dataframe

# %%
from collections import Counter

genre_counts = {}
for year in df['release_year'].unique():
    yearly_genres = [genre for genres in df[df['release_year'] == year]['genres'] for genre in genres]
    genre_counts[year] = Counter(yearly_genres)

genre_df = pd.DataFrame(genre_counts).T.fillna(0)

genre_df.head()
# Out:
#         Action  Adventure  Fantasy  Science Fiction  Family  Thriller  \
# 2009.0    51.0       36.0     22.0             32.0    28.0      59.0
# 2007.0    44.0       25.0     19.0             13.0    20.0      53.0
# 2015.0    46.0       35.0     10.0             28.0    17.0      67.0
# 2012.0    43.0       25.0     19.0             22.0    17.0      58.0
# 2010.0    49.0       30.0     21.0             19.0    29.0      56.0
#
#         Animation  Drama  Comedy  Mystery  Romance  Music  History  Crime  \
# 2009.0       15.0  122.0    97.0     28.0     57.0   11.0      8.0   32.0
# 2007.0       10.0   97.0    67.0     17.0     37.0   11.0      9.0   28.0
# 2015.0       13.0   95.0    52.0     20.0     23.0    8.0      9.0   26.0
# 2012.0       13.0   79.0    80.0      8.0     39.0    7.0      4.0   27.0
# 2010.0       13.0  115.0    87.0     17.0     45.0    2.0      8.0   30.0
#
#         Documentary  Horror  War  Foreign  Western  TV Movie
# ...

# %% [markdown]
# Now that the dataset has been created, we can now get into visualizing it.
#
# But first we need to calculate the total counts to see the overall popularity of the genres.

# %%
genre_df.sum().sort_values(ascending=False)
# Out:
# Drama              2300.0
# Comedy             1723.0
# Thriller           1275.0
# Action             1156.0
# Romance             895.0
# Adventure           792.0
# Crime               697.0
# Science Fiction     538.0
# Horror              520.0
# Family              514.0
# Fantasy             425.0
# Mystery             348.0
# Animation           234.0
# History             197.0
# Music               185.0
# War                 144.0
# Documentary         110.0
# Western              82.0
# Foreign              34.0
# TV Movie              8.0
# dtype: float64

# %% [markdown]
# We can plot this:

# %%
# we can have the genres on the x axis which in this case are the index arranged in decreasing order
#total count values on the y axis similarly arranged in decreasing order.
plt.figure(figsize=(12, 6))
sns.barplot(x=genre_df.sum().sort_values(ascending=False).index, y=genre_df.sum().sort_values(ascending=False).values, color='green')
plt.xlabel('Genre')
plt.ylabel('Total Count')
plt.title('Total Count of Movies by Genre')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We can now plot the number of movies for each genre over time using a line chart to see how the popularity of each genre has changed.

# %%
plt.figure(figsize=(12, 6))
for genre in genre_df.columns:
  plt.plot(genre_df.index, genre_df[genre], label=genre)
  plt.xlabel('Year')
  plt.ylabel('Number of Movies')
  plt.title('Popularity of Genres Over Time')
  plt.legend()

# %% [markdown]
# Seeing it be alittle bit crowded, we can try to filter out and see what the distribution for a specific genre, lets say, action, across the years will be.

# %%
# Filter the genre_df for the 'Action' genre
action_df = genre_df['Action']

# Plot the number of action movies over time
plt.figure(figsize=(12, 6))
plt.bar(action_df.index, action_df.values, label='Action', width=0.8, color='red')
plt.xlabel('Year')
plt.ylabel('Number of Action Movies')
plt.title('Popularity of Action Movies Over Time')
plt.legend()
plt.show()

# %% [markdown]
# This looks better!

# %% [markdown]
# ***Ratings and Popularity***
#
# Lets have a look at the top 10 highest rated and popular movies and check for ourselves if being rated better means that a movie is popular

# %%
plt.figure(figsize=(36,18))
#First subplot
plt.subplot(1,2,1)
plt.title('TOP 10 MOVIES WITH HIGHEST RATING')
sns.barplot(y='title', x='vote_average', data=df[['title', 'vote_average']].sort_values('vote_average', ascending=False).head(10), color='blue')
plt.xlabel('Rating')

# Second subplot
plt.subplot(1,2,2)
plt.title('TOP 10 MOVIES WITH HIGHEST POPULARITY')
sns.barplot(y='title', x='popularity', data=df[['title', 'popularity']].sort_values('popularity', ascending=False).head(10), color='red')
plt.xlabel('Popularity')
plt.show()

# %% [markdown]
# From the information above its very clear that the two are not interlinked in any way.

# %% [markdown]
# ## **Correlation Matrices and Heatmaps**

# %% [markdown]
# To conclude the exploration pahse we can start of by displaying the correlation heatmap of the different numerical columns in the dataset

# %%
# Select only numerical columns for correlation analysis
movie_num_df = df.select_dtypes(include=['int64', 'float64'])

# Compute the correlation matrix
correlation_matrix = movie_num_df.corr()

correlation_matrix
# Out:
#                 budget  popularity   revenue   runtime  vote_average  \
# budget        1.000000    0.505388  0.730286  0.269848      0.092567
# popularity    0.505388    1.000000  0.644582  0.225800      0.273964
# revenue       0.730286    0.644582  1.000000  0.251206      0.197087
# runtime       0.269848    0.225800  0.251206  1.000000      0.374159
# vote_average  0.092567    0.273964  0.197087  0.374159      1.000000
# vote_count    0.593096    0.778205  0.781395  0.272256      0.313002
# release_year  0.170070    0.102230  0.090051 -0.166369     -0.198487
#
#               vote_count  release_year
# budget          0.593096      0.170070
# popularity      0.778205      0.102230
# revenue         0.781395      0.090051
# runtime         0.272256     -0.166369
# vote_average    0.313002     -0.198487
# vote_count      1.000000      0.114323
# release_year    0.114323      1.000000

# %% [markdown]
# Taking all variables into account, we can now create a heat map that
# indicates the correlation between each of the variables with one another.

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Next on we head to Tableau to develop a more comprehensive dashboard
